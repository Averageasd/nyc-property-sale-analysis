# %%
import json
import io
import hashlib
import pandas as pd
import pyarrow as pa

# %%
df = pd.read_parquet('sales_si_04.parquet')

# %%
df.head()
# Out:
#          BOROUGH               NEIGHBORHOOD  \
# 0  Staten Island  ANNADALE
# 1  Staten Island  ANNADALE
# 2  Staten Island  ANNADALE
# 3  Staten Island  ANNADALE
# 4  Staten Island  ANNADALE
#
#                         BUILDING_CLASS_CATEGORY TAX_CLASS_BEFORE_SALE  BLOCK  \
# 0  01  ONE FAMILY HOMES                                             1   5402
# 1  01  ONE FAMILY HOMES                                             1   5406
# 2  01  ONE FAMILY HOMES                                             1   5407
# 3  01  ONE FAMILY HOMES                                             1   5425
# 4  01  ONE FAMILY HOMES                                             1   6205
#
#    LOT BUILDING_CLASS_BEFORE_SALE                                    ADDRESS  \
# 0   17                         A2  6 WEAVER STREET
# 1   23                         A1  1666 ARDEN AVE
# 2   36                         A1  183 BATHGATE STREET
# 3   31                         A2  7 SANDGAP STREET
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11942 entries, 0 to 11941
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         11942 non-null  string
#  1   NEIGHBORHOOD                    11942 non-null  string
#  2   BUILDING_CLASS_CATEGORY         11942 non-null  object
#  3   TAX_CLASS_BEFORE_SALE           11942 non-null  object
#  4   BLOCK                           11942 non-null  int64
#  5   LOT                             11942 non-null  int64
#  6   BUILDING_CLASS_BEFORE_SALE      11942 non-null  object
#  7   ADDRESS                         11942 non-null  string
#  8   APARTMENT_NUMBER                11942 non-null  object
#  9   ZIP_CODE                        11942 non-null  int64
#  10  RESIDENTIAL_UNITS               11942 non-null  int32
#  11  COMMERCIAL_UNITS                11942 non-null  int32
# ...

# %%
df.loc[df['ZIP_CODE'] == 0]
# Out:
# Empty DataFrame
# Columns: [BOROUGH, NEIGHBORHOOD, BUILDING_CLASS_CATEGORY, TAX_CLASS_BEFORE_SALE, BLOCK, LOT, BUILDING_CLASS_BEFORE_SALE, ADDRESS, APARTMENT_NUMBER, ZIP_CODE, RESIDENTIAL_UNITS, COMMERCIAL_UNITS, TOTAL_UNITS, LAND_SQUARE_FEET, GROSS_SQUARE_FEET, YEAR_BUILT, TAX_CLASS_AT_TIME_OF_SALE, BUILDING_CLASS_AT_TIME_OF_SALE, SALE_PRICE, SALE_DATE, ID]
# Index: []
#
# [0 rows x 21 columns]
